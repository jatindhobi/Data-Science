# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\5th Sem\Data-Science\Datasets\Youth_Tobacco_Survey__YTS__Data.csv")
df
# Out:
#        YEAR LocationAbbr   LocationDesc                  TopicType  \
# 0      2004           OH           Ohio  Tobacco Use – Survey Data
# 1      2008           AL        Alabama  Tobacco Use – Survey Data
# 2      2015           WV  West Virginia  Tobacco Use – Survey Data
# 3      2005           IL       Illinois  Tobacco Use – Survey Data
# 4      2005           CT    Connecticut  Tobacco Use – Survey Data
# ...     ...          ...            ...                        ...
# 10595  2002           KS         Kansas  Tobacco Use – Survey Data
# 10596  2015           IL       Illinois  Tobacco Use – Survey Data
# 10597  2010           WI      Wisconsin  Tobacco Use – Survey Data
# 10598  2009           LA      Louisiana  Tobacco Use – Survey Data
# 10599  2010           DE       Delaware  Tobacco Use – Survey Data
#
#                            TopicDesc  \
# 0              Cigarette Use (Youth)
# 1              Cigarette Use (Youth)
# 2      Smokeless Tobacco Use (Youth)
# ...

# %%
df.head()
# Out:
#    YEAR LocationAbbr   LocationDesc                  TopicType  \
# 0  2004           OH           Ohio  Tobacco Use – Survey Data
# 1  2008           AL        Alabama  Tobacco Use – Survey Data
# 2  2015           WV  West Virginia  Tobacco Use – Survey Data
# 3  2005           IL       Illinois  Tobacco Use – Survey Data
# 4  2005           CT    Connecticut  Tobacco Use – Survey Data
#
#                        TopicDesc     MeasureDesc DataSource  Response  \
# 0          Cigarette Use (Youth)  Smoking Status        YTS      Ever
# 1          Cigarette Use (Youth)  Smoking Status        YTS      Ever
# 2  Smokeless Tobacco Use (Youth)     User Status        YTS  Frequent
# 3          Cigarette Use (Youth)  Smoking Status        YTS      Ever
# 4  Smokeless Tobacco Use (Youth)     User Status        YTS      Ever
#
#   Data_Value_Unit Data_Value_Type  ...                    GeoLocation  \
# 0               %      Percentage  ...  (40.060210141, -82.404260056)
# ...

# %%
df.tail()
# Out:
#        YEAR LocationAbbr LocationDesc                  TopicType  \
# 10595  2002           KS       Kansas  Tobacco Use – Survey Data
# 10596  2015           IL     Illinois  Tobacco Use – Survey Data
# 10597  2010           WI    Wisconsin  Tobacco Use – Survey Data
# 10598  2009           LA    Louisiana  Tobacco Use – Survey Data
# 10599  2010           DE     Delaware  Tobacco Use – Survey Data
#
#                            TopicDesc  \
# 10595  Smokeless Tobacco Use (Youth)
# 10596          Cigarette Use (Youth)
# 10597              Cessation (Youth)
# 10598          Cigarette Use (Youth)
# 10599          Cigarette Use (Youth)
#
#                                              MeasureDesc DataSource  Response  \
# 10595                                        User Status        YTS  Frequent
# 10596                                     Smoking Status        YTS  Frequent
# 10597  Quit Attempt in Past Year Among Current Cigare...        YTS       NaN
# ...

# %%
df[["YEAR","LocationDesc"]]
# Out:
#        YEAR   LocationDesc
# 0      2004           Ohio
# 1      2008        Alabama
# 2      2015  West Virginia
# 3      2005       Illinois
# 4      2005    Connecticut
# ...     ...            ...
# 10595  2002         Kansas
# 10596  2015       Illinois
# 10597  2010      Wisconsin
# 10598  2009      Louisiana
# 10599  2010       Delaware
#
# [10600 rows x 2 columns]
