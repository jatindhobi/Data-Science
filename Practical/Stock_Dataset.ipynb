# %%
import pandas as pd
import numpy as np
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv(r"C:\5th Sem\Data-Science\Datasets\top_10_stock_data.csv")[0:10]
df
# Out:
#          Date Ticker       Open       High        Low      Close  Adj Close  \
# 0  2015-01-02   AAPL  27.847500  27.860001  26.837500  27.332500  24.373959
# 1  2015-01-05   AAPL  27.072500  27.162500  26.352501  26.562500  23.687313
# 2  2015-01-06   AAPL  26.635000  26.857500  26.157499  26.565001  23.689535
# 3  2015-01-07   AAPL  26.799999  27.049999  26.674999  26.937500  24.021711
# 4  2015-01-08   AAPL  27.307501  28.037500  27.174999  27.972500  24.944679
# 5  2015-01-09   AAPL  28.167500  28.312500  27.552500  28.002501  24.971436
# 6  2015-01-12   AAPL  28.150000  28.157499  27.200001  27.312500  24.356121
# 7  2015-01-13   AAPL  27.857500  28.200001  27.227501  27.555000  24.572378
# 8  2015-01-14   AAPL  27.260000  27.622499  27.125000  27.450001  24.478741
# 9  2015-01-15   AAPL  27.500000  27.514999  26.665001  26.705000  23.814377
#
#       Volume
# 0  212818400
# 1  257142000
# 2  263188400
# 3  160423600
# 4  237458000
# 5  214798000
# 6  198603200
# 7  268367600
# ...

# %%
df[["Date","Open"]]
# Out:
#          Date       Open
# 0  2015-01-02  27.847500
# 1  2015-01-05  27.072500
# 2  2015-01-06  26.635000
# 3  2015-01-07  26.799999
# 4  2015-01-08  27.307501
# 5  2015-01-09  28.167500
# 6  2015-01-12  28.150000
# 7  2015-01-13  27.857500
# 8  2015-01-14  27.260000
# 9  2015-01-15  27.500000

# %%
text=df.Ticker[0]
text
# Out:
# 'AAPL'

# %%
obj=WordCloud().generate(text)
obj

# %%
plt.imshow(obj,interpolation='bilinear')

# %%
sb.histplot(data=df,x='Open',hue='Close')
# Out:
# <Axes: xlabel='Open', ylabel='Count'>

# %%
sb.displot(data=df,x='Open',hue='Close',col='Close')

# %%
plt.plot(["Maths","English","Science","Hindi","Sanskrit"],[78,85,57,97,99])
plt.title("Marks")
plt.xlabel("Subject")
plt.ylabel("Marks")
plt.show()

# %%
plt.bar(df["Date"],df["Open"])
# Out:
# <BarContainer object of 10 artists>

# %%
plt.scatter(x=df["Date"],y=df["Open"],c='000000')

# %%
plt.plot(df["Date"],df["Open"],"^r")

# %%
x=df[['Open']]
y=df[['Close']]

# %%
model=LinearRegression()
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2,train_size=0.8,random_state=10)

model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
df
# Out:
#          Date Ticker       Open       High        Low      Close  Adj Close  \
# 0  2015-01-02   AAPL  27.847500  27.860001  26.837500  27.332500  24.373959
# 1  2015-01-05   AAPL  27.072500  27.162500  26.352501  26.562500  23.687313
# 2  2015-01-06   AAPL  26.635000  26.857500  26.157499  26.565001  23.689535
# 3  2015-01-07   AAPL  26.799999  27.049999  26.674999  26.937500  24.021711
# 4  2015-01-08   AAPL  27.307501  28.037500  27.174999  27.972500  24.944679
# 5  2015-01-09   AAPL  28.167500  28.312500  27.552500  28.002501  24.971436
# 6  2015-01-12   AAPL  28.150000  28.157499  27.200001  27.312500  24.356121
# 7  2015-01-13   AAPL  27.857500  28.200001  27.227501  27.555000  24.572378
# 8  2015-01-14   AAPL  27.260000  27.622499  27.125000  27.450001  24.478741
# 9  2015-01-15   AAPL  27.500000  27.514999  26.665001  26.705000  23.814377
#
#       Volume
# 0  212818400
# 1  257142000
# 2  263188400
# 3  160423600
# 4  237458000
# 5  214798000
# 6  198603200
# 7  268367600
# ...

# %%
model.predict([[27.072500]])
# Out:
# c:\Users\jatin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[26.99941273]])
