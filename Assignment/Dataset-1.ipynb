# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv(r"C:\5th Sem\Data-Science\Assignment\Datasets\FOOD-DATA-GROUP4.csv")
df
# Out:
#      Unnamed: 0.1  Unnamed: 0                        food  Caloric Value  \
# 0               0           0  chocolate pudding fat free            105
# 1               1           1             tapioca pudding            143
# 2               2           2    tapioca pudding fat free            105
# 3               3           3                rice pudding            122
# 4               4           4                corn pudding            328
# ..            ...         ...                         ...            ...
# 227           227         227       muesli master crumble            124
# 228           228         228                 bran flakes            131
# 229           229         229                  nut cereal            245
# 230           230         230                 corn flakes            108
# 231           231         231              corn grits dry             36
#
#       Fat  Saturated Fats  Monounsaturated Fats  Polyunsaturated Fats  \
# ...

# %%
y=df[['Saturated Fats']]
x=df[['Fat']]

model=LinearRegression()
x_test, x_train, y_test, y_train = train_test_split(x,y,test_size=0.2,train_size=0.8,random_state=100)

model.fit(x_train,y_train)

model.predict([[12.6]])
# Out:
# c:\Users\jatin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[2.83301523]])
